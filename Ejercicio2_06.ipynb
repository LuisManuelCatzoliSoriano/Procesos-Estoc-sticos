# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisManuelCatzoliSoriano/Procesos-Estoc-sticos/blob/main/Ejercicio2_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejemplo:
#
# Sea
#
# $$
#  \begin{pmatrix}
# 0 & 2 & 3 & 0 \\
# 4 & 0 & 2 & 0 \\
# 0 & 2 & 0 & 2 \\
# 1 & 0 & 3 & 0 \\
# \end{pmatrix}
# $$
#
# Al calcular $\hat{P}$
#
# $$\hat{P}= \begin{pmatrix}
# \frac{1}{6} & \frac{2}{6} & \frac{1}{6} & 0 \\
# \frac{4}{6} & 0 & \frac{2}{6} & 0 \\
# 0 & \frac{2}{6} & \frac{2}{6} & \frac{2}{6} \\
# \frac{1}{6} & 0 & \frac{3}{6} & \frac{2}{6} \\
# \end{pmatrix}$$

# %% [markdown]
# 1) Escribir $P(t)$ usando ek teorema del ejemplo anterior.

# %% [markdown]
# Para empezar primero calculamos $M$

# %%
r=6
t=0.5

M=np.maximum(r*t+5*np.sqrt(r*t),20)
M
# Out:
# np.float64(20.0)

# %%
import numpy as np

# %%
def P(t,r,M,Pe):
  P=np.matrix(zeros)
  for i in range(M):
    P+=np.e(r*t)*(r*t)\
