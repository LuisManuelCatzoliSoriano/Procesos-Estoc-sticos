# %% [markdown]
# <a href="https://colab.research.google.com/github/LuisManuelCatzoliSoriano/Procesos-Estoc-sticos/blob/main/Clase21_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ¿Es regular?

# %%
import numpy as np
import sympy as sp

# %%
A=np.matrix([[0, 0, 0, 0, 1],
            [0.25, 0, 0, 0.5, 0.25],
            [0, 0, 1, 0, 0],
            [0, 0, 0.5, 0.5, 0],
            [0.25, 0.5, 0, 0, 0.25]])

# %%
np.power(A, 3)
# Out:
# matrix([[0.      , 0.      , 0.      , 0.      , 1.      ],
#         [0.015625, 0.      , 0.      , 0.125   , 0.015625],
#         [0.      , 0.      , 1.      , 0.      , 0.      ],
#         [0.      , 0.      , 0.125   , 0.125   , 0.      ],
#         [0.015625, 0.125   , 0.      , 0.      , 0.015625]])

# %% [markdown]
# Si al elevar la matriz a dos potencias sucesivas los ceros se mantienen en la misma posición, entonces la matriz no es regular.

# %% [markdown]
# # Encontrar la distribución límite de

# %%
B=sp.Matrix([[1/3, 1/2, 1/6], [1/2, 1/2, 0], [1/4, 1/2, 1/4]])

# %% [markdown]
# Primero verificamos que la matriz es regular

# %%
np.power(B, 2)
# Out:
# array([[0.111111111111111, 0.250000000000000, 0.0277777777777778],
#        [0.250000000000000, 0.250000000000000, 0],
#        [0.0625000000000000, 0.250000000000000, 0.0625000000000000]],
#       dtype=object)

# %%
x, y, z = sp.symbols('x y z')
v=sp.Matrix([[x],[y],[z]])

# %%
ec1 =B.col(0).dot(v)
ec2 =B.col(1).dot(v)
ec3 =B.col(2).dot(v)

# %%
e1=sp.Eq(ec1, x)
e2=sp.Eq(ec2, y)
e3=sp.Eq(ec3, z)
e4=sp.Eq(x+y+z,1)

# %%
sol=sp.solve((e1,e2, e4), (x,y,z))
sol
# Out:
# {x: 0.409090909090909, y: 0.500000000000000, z: 0.0909090909090909}
